# %% [markdown]
# # Fire Up Graph Lab Create

# %%
import graphlab

# %% [markdown]
# # Load up house sales data

# %%
sales = graphlab.SFrame('home_data.gl/')
# Out:
# /opt/conda/lib/python2.7/site-packages/requests/packages/urllib3/connection.py:266: SubjectAltNameWarning: Certificate for beta.graphlab.com has no `subjectAltName`, falling back to check for a `commonName` for now. This feature is being removed by major browsers and deprecated by RFC 2818. (See https://github.com/shazow/urllib3/issues/497 for details.)
#   SubjectAltNameWarning
# 2016-06-27 05:15:13,928 [INFO] graphlab.cython.cy_server, 176: GraphLab Create v1.9 started. Logging: /tmp/graphlab_server_1467004513.log
# This non-commercial license of GraphLab Create is assigned to de955@snu.edu.in and will expire on May 03, 2017. For commercial licensing options, visit https://dato.com/buy/.

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# ...

# %%
graphlab.canvas.set_target('ipynb')
sales.show(view = "Scatter Plot", x = "sqft_living", y = "price")

# %%
graphlab.canvas.set_target('ipynb')
sales.show()
